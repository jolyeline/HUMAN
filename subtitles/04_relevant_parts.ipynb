# %% [markdown]
# # Filtering Text for Relevance

# %%
# imports
import pandas as pd
import re
import ast
from html import escape
from IPython.display import display, HTML

# %%
# read the CSV file into a DataFrame
df = pd.read_csv('subtitles_ai_related.csv', index_col=0)

# %%
old_df = df.copy()
# delete rows with mention of "songfestical" (false positives)
df = df[~df['text_clean'].str.contains('songfestival', case=False, na=False)]
# show how many rows dropped
dropped = len(old_df) - len(df)
print(f"Dropped {dropped} rows with 'songfestival' mentions.")
# Out:
# Dropped 42 rows with 'songfestival' mentions.

# %%
import ast

def to_list(val):
    if isinstance(val, list):
        return val
    if isinstance(val, str):
        try:
            return ast.literal_eval(val)
        except (ValueError, SyntaxError):
            return []
    return []

df['matched_keywords_all'] = df.apply(
    lambda row: to_list(row['company_hits']) + to_list(row['matched_keywords_all']),
    axis=1
)
df['matched_keywords_all'].iloc[0]
# Out:
# ['facebook', 'google', 'twitter', 'algoritme']

# %%
#drop rows
df = df.drop(columns=['company_hits', 'matched_keywords_title', 'matched_keywords_body', 'n_hits_title_total', 'n_hits_body_total'])

# %%
df
# Out:
#                        filename                program  year  \
# 47           2016-11-16-19,00-1  de wereld draait door  2016
# 52           2016-02-08-23,04-1                  jinek  2016
# 56    GOEDEMORGEN_N-WON02434179  goedemorgen nederland  2023
# 74    GOEDEMORGEN_N-WON02298553  goedemorgen nederland  2022
# 153   GOEDEMORGEN_N-WON02108661  goedemorgen nederland  2020
# ...                         ...                    ...   ...
# 9928         2017-09-18-19,01-1  de wereld draait door  2017
# 9936  GOEDEMORGEN_N-WON02358587  goedemorgen nederland  2022
# 9941         2018-04-27-08,38-1  goedemorgen nederland  2018
# 9946  GOEDEMORGEN_N-WON02320372  goedemorgen nederland  2022
# 9955  GOEDEMORGEN_N-WON02221078  goedemorgen nederland  2021
#
#                                              text_clean ai_related  \
# 47    Eelco Bosch van Rosenthal, Dirk Jan Roeleven, ...        yes
# 52    Uitzending bijwonen? Dat kan. Ga naar jinek.kr...        yes
# 56    en Joodse scholen die hun deuren vandaag dicht...        yes
# 74    888\nWelkom terug bij Goedemorgen Nederland.\n...        yes
# 153   888\nWelkom terug bij Goedemorgen Nederland.\n...        yes
# ...                                                 ...        ...
# 9928  888\nGeerte Piening, Bahar Goodarzi, Jeroen Wo...        yes
# 9936  888\nGoedemorgen Nederland, welkom terug bij W...        yes
# 9941  888\nGoedemorgen Nederland, het is vandaag vri...        yes
# 9946  888\nWelkom terug bij Goedemorgen Nederland.\n...        yes
# 9955  888\nWelkom terug bij Goedemorgen Nederland.\n...        yes
#
#                         matched_keywords_all
# 47    [facebook, google, twitter, algoritme]
# 52                                  [drones]
# 56           [ai, kunstmatige intelligentie]
# 74      [twitter, kunstmatige intelligentie]
# 153                                  [drone]
# ...                                      ...
# 9928              [facebook, twitter, robot]
# 9936                         [drone, drones]
# 9941                       [twitter, drones]
# 9946                            [ai, drones]
# 9955                                 [robot]
#
# [506 rows x 6 columns]

# %%
def inspect_ai_related(df, program, body='relevant_section',  num_samples=30, random_state=42):
    """
    Displays random samples with highlighted *matched* keywords.
    Uses df['matched_keywords_all'] per row instead of a global keyword list.
    """
    
    # --- sanity checks ---
    if 'ai_related' not in df.columns:
        raise KeyError("DataFrame must contain an 'ai_related' column.")
    if not {'program', body}.issubset(df.columns):
        missing = {'program', body} - set(df.columns)
        raise KeyError(f"Missing required column(s): {missing}")
    if 'matched_keywords_all' not in df.columns:
        raise KeyError("DataFrame must contain 'matched_keywords_all'.")

    # # --- sample ---
    # n = min(num_samples, len(df))
    # samples = df.sample(n=n, random_state=random_state)

    # --- sample ---
    
    if program == "all":
        pool = df
    else:
        pool = df[df['program'] == program]
       
    
      

    n = min(num_samples, len(pool))
    samples = pool.sample(n=n, random_state=random_state)


    # --- internal highlight function ---
    def highlight_keywords(text, keywords):
        if pd.isna(text):
            return ""
        s = str(text)

        if not isinstance(keywords, (set, list)):
            raise ValueError("Keywords must be a set or list")
        kws = {str(w).strip().lower() for w in keywords if str(w).strip()}
        if not kws:
            return s

        # sort by length to avoid partial overshadowing
        ordered = sorted(kws, key=len, reverse=True)

        # custom boundary: match even inside hyphenated words
        def make_pattern(word):
            return rf'(?<![A-Za-z0-9]){re.escape(word)}(?![A-Za-z0-9])'

        combined = "|".join(make_pattern(w) for w in ordered)
        regex = re.compile(combined, flags=re.IGNORECASE)

        def repl(m):
            kw = m.group(0)
            return f'<span style="font-size:1.5em; font-weight:bold; color:green;">{escape(kw)}</span>'

        return regex.sub(repl, s)

    # --- display samples ---
    for idx, row in samples.iterrows():
        
        ai_val = row['ai_related']
        title = row['program']
        body_text = row[body]  # ✅ 'body' parameter stays intact

         # --- use the actually matched keywords in this row ---
        matched_keywords = row.get('matched_keywords_all', [])
        if isinstance(matched_keywords, (list, set, tuple)):
            row_terms = {str(x).lower() for x in matched_keywords}
        else:
            row_terms = {str(matched_keywords).lower()} if matched_keywords else set()

        # --- highlight ---
        highlighted_title = highlight_keywords(title, row_terms)
        highlighted_body  = highlight_keywords(body_text, row_terms)

        # --- header ---
        header_html = (
            f'<div style="margin:0.5em 0;">'
            f'<strong>Index:</strong> {idx} &nbsp; | &nbsp; '
            f'<strong>ai_related:</strong> {ai_val}'
        )
        if matched_keywords:
            header_html += f'<br><strong>matched keywords:</strong> {matched_keywords}'
        header_html += '</div>'

        # --- display ---
        display(HTML(header_html))
        display(HTML(f'<h3 style="margin:0.2em 0;">{highlighted_title}</h3>'))
        display(HTML(f'<div style="line-height:1.5;">{highlighted_body}</div>'))
        display(HTML('<hr>'))

    print(f"Displayed {n} random articles (with row-specific matched keywords highlighted).")
    return samples

# %%
import re
import ast
import pandas as pd

def _norm_matched_keywords(val):
    """
    Normalize matched_keywords_all into a list[str].
    Accepts: list/set/tuple, stringified list (e.g. "['ai','ml']"),
             or comma-separated string ("ai, machine learning").
    """
    if val is None or (isinstance(val, float) and pd.isna(val)):
        return []
    if isinstance(val, (list, set, tuple)):
        kws = list(val)
    elif isinstance(val, str):
        s = val.strip()
        if not s:
            return []
        # Try to parse stringified list
        try:
            parsed = ast.literal_eval(s)
            if isinstance(parsed, (list, set, tuple)):
                kws = list(parsed)
            else:
                # fallback: treat as comma-separated
                kws = [x.strip() for x in s.split(",") if x.strip()]
        except Exception:
            kws = [x.strip() for x in s.split(",") if x.strip()]
    else:
        return []

    # clean, dedupe, keep phrases
    out = []
    seen = set()
    for k in kws:
        if not isinstance(k, str):
            continue
        k2 = k.strip()
        if not k2:
            continue
        kl = k2.lower()
        if kl not in seen:
            seen.add(kl)
            out.append(k2)
    return out

def _extract_windows(text, keywords, window=5, max_snippets=5):
    """
    Build a plain-text section composed of ±window words around each keyword hit.
    Returns: (section_text, spans, n_matches)
    """
    if not isinstance(text, str) or not text.strip():
        return "", [], 0
    keywords = _norm_matched_keywords(keywords)
    if not keywords:
        return "", [], 0

    # Safer "word boundary" for phrases: (?<!\w) ... (?!\w)
    # (handles multi-word phrases and punctuation better than \b ... \b)
    alts = [re.escape(k) for k in keywords]
    pattern = r'(?<!\w)(?:' + '|'.join(alts) + r')(?!\w)'
    flags = re.IGNORECASE

    matches = list(re.finditer(pattern, text, flags))
    if not matches:
        return "", [], 0

    # Word spans to take ±window words
    word_spans = [(m.start(), m.end()) for m in re.finditer(r'\S+', text)]

    def word_index_for_pos(pos):
        # small linear scan is fine for typical lengths
        for i, (s, e) in enumerate(word_spans):
            if s <= pos < e:
                return i
        # if match starts on whitespace, snap to next word
        for i, (s, e) in enumerate(word_spans):
            if pos < e:
                return i
        return len(word_spans) - 1 if word_spans else 0

    spans = []
    for m in matches:
        wi = word_index_for_pos(m.start())
        start_w = max(0, wi - window)
        end_w   = min(len(word_spans), wi + window + 1)
        start_c = word_spans[start_w][0]
        end_c   = word_spans[end_w - 1][1]

        if spans and start_c <= spans[-1][1]:
            spans[-1] = (spans[-1][0], max(spans[-1][1], end_c))
        else:
            spans.append((start_c, end_c))

    spans = spans[:max_snippets]

    parts = []
    for i, (s, e) in enumerate(spans):
        prefix = '...' if (i == 0 and s > 0) else ''
        suffix = '...' if (i == len(spans)-1 and e < len(text)) else ''
        parts.append(prefix + text[s:e].strip() + suffix)

    section_text = ' '.join(parts)
    return section_text, spans, len(matches)

def add_relevant_section(df, body_col='body', matched_col='matched_keywords_all',
                         window=5, max_snippets=5):
    """
    Adds:
      - relevant_section (plain text)
      - relevant_section_spans (char spans)
      - n_keyword_matches
      - relevant_len_chars
      - relevant_len_words
    """
    results = df.apply(
        lambda r: _extract_windows(
            str(r[body_col]) if pd.notna(r.get(body_col)) else "",
            r.get(matched_col),
            window,
            max_snippets
        ),
        axis=1
    )
    df['relevant_section']       = results.map(lambda t: t[0])
    df['relevant_section_spans'] = results.map(lambda t: t[1])
    df['n_keyword_matches']      = results.map(lambda t: t[2])
    df['relevant_len_chars']     = df['relevant_section'].str.len()
    df['relevant_len_words']     = df['relevant_section'].str.count(r'\b\w+\b')
    return df

# %%
df_relevant = add_relevant_section(df, body_col='text_clean', matched_col='matched_keywords_all', window=50)
df_relevant
# Out:
#                        filename                program  year  \
# 47           2016-11-16-19,00-1  de wereld draait door  2016
# 52           2016-02-08-23,04-1                  jinek  2016
# 56    GOEDEMORGEN_N-WON02434179  goedemorgen nederland  2023
# 74    GOEDEMORGEN_N-WON02298553  goedemorgen nederland  2022
# 153   GOEDEMORGEN_N-WON02108661  goedemorgen nederland  2020
# ...                         ...                    ...   ...
# 9928         2017-09-18-19,01-1  de wereld draait door  2017
# 9936  GOEDEMORGEN_N-WON02358587  goedemorgen nederland  2022
# 9941         2018-04-27-08,38-1  goedemorgen nederland  2018
# 9946  GOEDEMORGEN_N-WON02320372  goedemorgen nederland  2022
# 9955  GOEDEMORGEN_N-WON02221078  goedemorgen nederland  2021
#
#                                              text_clean ai_related  \
# 47    Eelco Bosch van Rosenthal, Dirk Jan Roeleven, ...        yes
# 52    Uitzending bijwonen? Dat kan. Ga naar jinek.kr...        yes
# 56    en Joodse scholen die hun deuren vandaag dicht...        yes
# 74    888\nWelkom terug bij Goedemorgen Nederland.\n...        yes
# 153   888\nWelkom terug bij Goedemorgen Nederland.\n...        yes
# ...                                                 ...        ...
# 9928  888\nGeerte Piening, Bahar Goodarzi, Jeroen Wo...        yes
# 9936  888\nGoedemorgen Nederland, welkom terug bij W...        yes
# 9941  888\nGoedemorgen Nederland, het is vandaag vri...        yes
# 9946  888\nWelkom terug bij Goedemorgen Nederland.\n...        yes
# 9955  888\nWelkom terug bij Goedemorgen Nederland.\n...        yes
#
#                         matched_keywords_all  \
# 47    [facebook, google, twitter, algoritme]
# 52                                  [drones]
# 56           [ai, kunstmatige intelligentie]
# 74      [twitter, kunstmatige intelligentie]
# 153                                  [drone]
# ...                                      ...
# 9928              [facebook, twitter, robot]
# 9936                         [drone, drones]
# 9941                       [twitter, drones]
# 9946                            [ai, drones]
# 9955                                 [robot]
#
#                                        relevant_section  \
# 47    ...uit Amerika.\nVanochtend geland.\nHet Ameri...
# 52    ...over.\nEn onze tennisdames verrasten de wer...
# 56    ...en de neus van de politie.\nWeet u hoe een ...
# 74    ...zegt de Britse minister van buitenlandse za...
# 153   ...er aardig uit.\nIs het een quarantainecoup?...
# ...                                                 ...
# 9928  ...de Staten-Generaal' en niet 'mongool'.\nLev...
# 9936  ...prijsgeven...\nmaar wil aan buitenlandse bo...
# 9941  ...Zo gaat zij.\nHeel vrolijk.\nAnneke Nieuwen...
# 9946  ...weten het niet.\nMaar zij willen iets doen....
# 9955  ...een beetje in de gaten.\nIk wist niet dat h...
#
#                               relevant_section_spans  n_keyword_matches  \
# 47       [(352, 1482), (6045, 6620), (21504, 22090)]                  6
# 52                                  [(17898, 18694)]                  2
# 56                                    [(6024, 7855)]                  5
# 74                      [(704, 1351), (9419, 10034)]                  2
# 153                                   [(4852, 5768)]                  3
# ...                                              ...                ...
# 9928  [(2686, 3332), (10448, 10998), (21062, 21630)]                  4
# 9936                                  [(5358, 6309)]                  4
# 9941                    [(4217, 4778), (9012, 9573)]                  2
# 9946                    [(2787, 3368), (4133, 4709)]                  3
# 9955                                  [(7793, 8835)]                  4
#
#       relevant_len_chars  relevant_len_words
# 47                  2299                 392
# 52                   802                 131
# 56                  1837                 294
# 74                  1269                 204
# 153                  922                 166
# ...                  ...                 ...
# 9928                1772                 326
# 9936                 957                 153
# 9941                1129                 203
# 9946                1164                 204
# 9955                1048                 181
#
# [506 rows x 11 columns]

# %%
df = df.drop(columns=['relevant_section_spans', 'n_keyword_matches', 'relevant_len_chars', 'relevant_len_words'])

# %%
# # lowercase all programs for easier filtering
# df['program'] = df['program'].str.lower()

# %%
df['program'].unique()
# Out:
# <StringArray>
# ['de wereld draait door',                 'jinek', 'goedemorgen nederland',
#                    'eva',          'de vooravond',                  'pauw',
#               'bar laat',       'café kockelmann',                     'm']
# Length: 9, dtype: str

# %%
# relevant section statistics

# average relevant section length in characters per program
program_stats = df.groupby('program')['relevant_len_chars'].agg(['mean', 'median', 'count']).reset_index()
program_stats = program_stats.rename(columns={'mean': 'avg_relevant_len_chars', 'median': 'median_relevant_len_chars', 'count': 'n_articles'})
program_stats

# plot
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(data=program_stats, x='program', y='avg_relevant_len_chars')
plt.xticks(rotation=45, ha='right')
plt.title('Average Relevant Section Length (chars) by Program')
plt.xlabel('Program')
plt.ylabel('Average Relevant Section Length (chars)')
plt.tight_layout()
plt.show()

# plot avaerage section length compared to total length cleaned text per program
df['total_len_chars'] = df['text_clean'].str.len()
program_stats_full = df.groupby('program').agg(
    avg_relevant_len_chars=('relevant_len_chars', 'mean'),
    avg_total_len_chars=('total_len_chars', 'mean')
).reset_index()
program_stats_full['relevant_to_total_ratio'] = program_stats_full['avg_relevant_len_chars'] / program_stats_full['avg_total_len_chars']
program_stats_full

plt.figure(figsize=(10, 6))
sns.barplot(data=program_stats_full, x='program', y='relevant_to_total_ratio')
# # also plot total length as line
# sns.lineplot(data=program_stats_full, x='program', y='avg_total_len_chars', marker='o', color='orange', label='Avg Total Length (chars)')
# plt.legend(fontsize=8)  # smaller legend, with labels
plt.xticks(rotation=45, ha='right')
plt.title('Ratio of Relevant Section Length to Total Cleaned Text Length by Program')
plt.xlabel('Program')
plt.ylabel('Relevant Section Length / Total Cleaned Text Length')
plt.tight_layout()
plt.show()

# %%
# average ratio of relevant section length to total cleaned text length per program

program_stats_full.groupby('program')['relevant_to_total_ratio'].mean().reset_index()

# average ratio of relevant section length to total cleaned text length per program, sorted by ratio
program_stats_full.sort_values('relevant_to_total_ratio', ascending=False)[['program', 'relevant_to_total_ratio']].reset_index(drop=True)

# total average ratio overall programs
total_relevant = df['relevant_len_chars'].sum()
total_cleaned = df['total_len_chars'].sum()
total_average_ratio = total_relevant / total_cleaned if total_cleaned > 0 else 0
print(f"Total average ratio of relevant section length to total cleaned text length: {total_average_ratio:.2f}")
# Out:
# Total average ratio of relevant section length to total cleaned text length: 0.09

# %%
# # filter for certain keywords
# keywords_of_interest = ['programma']
# pattern = '|'.join([re.escape(k) for k in keywords_of_interest])
# df_filtered_keywords = df[df['matched_keywords_all'].apply(lambda kws: any(re.search(pattern, str(k), re.IGNORECASE) for k in to_list(kws)))]

# %%
# # search for "facebook" in the relevant_section as well (in case it was missed in the keyword matching)
# df_filtered_keywords = df[df['relevant_section'].str.contains('programma', case=False, na=False)]
# # add twitter to keywords for highlighting
# df_filtered_keywords['matched_keywords_all'] = df_filtered_keywords['matched_keywords_all'].apply(lambda kws: to_list(kws) + ['programma'])

# %%
# df_filtered_keywords.info()

# %%
# program = "all" to display from all programs, or specify a program like "jinek"
inspect_ai_related(df, body = 'relevant_section', num_samples=1, random_state=42, program='all')
# Out:
# <div style="margin:0.5em 0;"><strong>Index:</strong> 3509 &nbsp; | &nbsp; <strong>ai_related:</strong> yes<br><strong>matched keywords:</strong> ['ai', 'chatgpt', 'kunstmatige intelligentie']</div>
# <h3 style="margin:0.2em 0;">goedemorgen nederland</h3>
# <div style="line-height:1.5;">...en die kreeg te horen:
# uw huurcontract stopt, u moet op zoek naar een andere woning.
# En die woningen zijn niet ruim beschikbaar.
# Dan sta je als moeder met twee jonge kinderen mogelijk op straat.
# Of het verbieden van tijdelijke huurcontracten een oplossing is, daarover meer.
# Straks, Jean Dohmen over <span style="font-size:1.5em; font-weight:bold; color:green;">kunstmatige intelligentie</span>.
# Vandaag stemt het Europees Parlement over hoe grip te houden op deze nieuwe technologie.
# Eerst naar Jill.
# Het is nagelbijten voor tienduizenden pubers in ons land.
# De eindexamens beginnen vandaag.
# Vanaf 09.00 uur op het programma: filosofie voor havo, Duits voor vwo.
# Op het vmbo beginnen de examens iets binnen.
# Er is nu een biertje gebrouwen dat met recht een speciaal biertje is.
# Er zijn tegenwoordig allerlei superslimme computersystemen...
# die binnen een paar seconden een werkstuk van 20 pagina's voor je kan schrijven.
# Het enige dat je hoeft te doen is een paar steekwoorden invullen.
# Het kan bijvoorbeeld in <span style="font-size:1.5em; font-weight:bold; color:green;">ChatGPT</span>.
# Je kunt aan zo'n systeem van alles vragen.
# In dit geval dachten ze bij een Rotterdamse brouwerij:
# Wij laten het systeem een recept bedenken voor een biertje.
# Het begon met de vraag: hoe maak ik de beste lentebok?
# Inmiddels is het biertje geblikt in een etiket dat ook door zo'n hier brouwen met nul personen.
# Behalve het programmeren van het recept...
# tot aan de tank is volledig geautomatiseerd.
# Dat is een bijzonder stuk moderne techniek. Daar ben ik zeer trots op.
# Breda heeft ook een eigen bier, zegt u het.
# Ja, Bredabier.
# Wat zou je ervan vinden als dat via <span style="font-size:1.5em; font-weight:bold; color:green;">AI</span> gebrouwen wordt...
# is het dan nog net zo speciaal?
# Of raken we dan onze cultuur kwijt?
# Ik zei het al eerder, de Brabander...
# het maakt niet uit wie het biertje maakt, als het maar lekker smaakt.
# Natuurlijk blijft het iets wat door mensen moet worden gemaakt...
# maar ik kijk echt met spanning naar de smaak.
# U gaat hem proeven? Absoluut.
# Later meer over <span style="font-size:1.5em; font-weight:bold; color:green;">kunstmatige intelligentie</span>.
# Het is wel goed dat er menselijke controle blijft.
# Als <span style="font-size:1.5em; font-weight:bold; color:green;">ChatGPT</span> had gezegd:
# voer er bepaald gif aan toe.
# Dan had de brouwer het waarschijnlijk niet gedaan.
# Dat is wel het punt.
# Een mens moet wel het laatste woord houden over hoe het biertje wordt gebrouwen.
# Dus dit is een voorbeeld van hoe het moet? Van hoe het kan.
# Een gebeurtenis de woningen niet.
# Op de lange termijn wordt het een grote uitdaging.
# Maar op korte termijn zeg ik:
# maak gebruik van het bestaande woningvoorraad.
# 3,5 miljoen vierkante kilometer aan kantoorruimte staat leeg.
# Bouw dat om tot betaalbare woonruimte voor jongeren en starters.
# Straks FD-journalist Jean Dohmen over de gevaren van <span style="font-size:1.5em; font-weight:bold; color:green;">kunstmatige intelligentie</span>.
# Vandaag stemt Brussel over een wet die deze technologie moet controleren.
# We zijn er tot 10 uur. Blijf kijken. Nu eerst het NOS Journaal.</div>
# <hr>
# Displayed 1 random articles (with row-specific matched keywords highlighted).
#                        filename                program  year  \
# 3509  GOEDEMORGEN_N-WON02399764  goedemorgen nederland  2023
#
#                                              text_clean ai_related  \
# 3509  Goedemorgen Nederland.\nKleine verhuurders mak...        yes
#
#                           matched_keywords_all  \
# 3509  [ai, chatgpt, kunstmatige intelligentie]
#
#                                        relevant_section
# 3509  ...en die kreeg te horen:\nuw huurcontract sto...

# %%
df
# Out:
#                        filename                program  year  \
# 47           2016-11-16-19,00-1  de wereld draait door  2016
# 52           2016-02-08-23,04-1                  jinek  2016
# 56    GOEDEMORGEN_N-WON02434179  goedemorgen nederland  2023
# 153   GOEDEMORGEN_N-WON02108661  goedemorgen nederland  2020
# 189   GOEDEMORGEN_N-WON02301038  goedemorgen nederland  2022
# ...                         ...                    ...   ...
# 9914  BAR_LAAT_____-WON02531286               bar laat  2024
# 9928         2017-09-18-19,01-1  de wereld draait door  2017
# 9936  GOEDEMORGEN_N-WON02358587  goedemorgen nederland  2022
# 9946  GOEDEMORGEN_N-WON02320372  goedemorgen nederland  2022
# 9955  GOEDEMORGEN_N-WON02221078  goedemorgen nederland  2021
#
#                                              text_clean ai_related  \
# 47    Eelco Bosch van Rosenthal, Dirk Jan Roeleven, ...        yes
# 52    Uitzending bijwonen? Dat kan. Ga naar jinek.kr...        yes
# 56    en Joodse scholen die hun deuren vandaag dicht...        yes
# 153   888\nWelkom terug bij Goedemorgen Nederland.\n...        yes
# 189   888\nWelkom terug bij Goedemorgen Nederland.\n...        yes
# ...                                                 ...        ...
# 9914  888\nGoedenavond.\nSuse van Kleef, Michiel Rom...        yes
# 9928  888\nGeerte Piening, Bahar Goodarzi, Jeroen Wo...        yes
# 9936  888\nGoedemorgen Nederland, welkom terug bij W...        yes
# 9946  888\nWelkom terug bij Goedemorgen Nederland.\n...        yes
# 9955  888\nWelkom terug bij Goedemorgen Nederland.\n...        yes
#
#                  matched_keywords_all  \
# 47      [facebook, google, algoritme]
# 52                           [drones]
# 56    [ai, kunstmatige intelligentie]
# 153                           [drone]
# 189                [facebook, drones]
# ...                               ...
# 9914                     [google, ai]
# 9928                [facebook, robot]
# 9936                  [drone, drones]
# 9946                     [ai, drones]
# 9955                          [robot]
#
#                                        relevant_section
# 47    ...uit Amerika.\nVanochtend geland.\nHet Ameri...
# 52    ...over.\nEn onze tennisdames verrasten de wer...
# 56    ...en de neus van de politie.\nWeet u hoe een ...
# 153   ...er aardig uit.\nIs het een quarantainecoup?...
# 189   ...bereid om heel ver te gaan.\nHet bombardere...
# ...                                                 ...
# 9914  ...meer over de nieuwe misstanden bij het Arnh...
# 9928  ...de Staten-Generaal' en niet 'mongool'.\nLev...
# 9936  ...prijsgeven...\nmaar wil aan buitenlandse bo...
# 9946  ...weten het niet.\nMaar zij willen iets doen....
# 9955  ...een beetje in de gaten.\nIk wist niet dat h...
#
# [440 rows x 7 columns]

# %%
df.to_csv('final_df.csv')

# %%
# plot distribution of relevant section lengths in characters
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6)) 
sns.histplot(df['relevant_len_chars'], bins=30, kde=True)
plt.title('Distribution of Relevant Section Lengths (chars)')
plt.xlabel('Relevant Section Length (chars)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 import seaborn as sns
#       4 plt.figure(figsize=(10, 6))
# ----> 5 sns.histplot(df['relevant_len_chars'], bins=30, kde=True)
#       6 plt.title('Distribution of Relevant Section Lengths (chars)')
#       7 plt.xlabel('Relevant Section Length (chars)')
#
# NameError: name 'df' is not defined
