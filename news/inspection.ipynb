# %%
# imports

import pandas as pd

# %%
df = pd.read_csv("news_classified.csv", index_col=0)

# %%
df.head()
# Out:
#    Unnamed: 0                                              title outlet  \
# 0           0                            Waardigheid Waardigheid     TR
# 1           1  Benoeming Selmayr 'soort staatsgreep' Benoemin...     TR
# 2           2  May woedend over Brussels ontwerp-akkoord May ...     TR
# 3           3                                      Streep Streep     TR
# 4           4  De stad die muziek ademt De stad die muziek ademt     TR
#
#          date            authors  \
# 0  2018-05-01  SYLVAIN EPHIMENCO
# 1  2018-04-19  CHRISTOPH SCHMIDT
# 2  2018-03-01         TIM DE WIT
# 3  2018-03-01  SYLVAIN EPHIMENCO
# 4  2018-04-28    JOHAN NEBBELING
#
#                                                 body  word_count ai_related  \
# 0  Ephimenco\nWat hebben jullie toch met lijden?'...         297         no
# 1  Het Europarlement heeft strikt genomen niets t...         233         no
# 2  De Britse premier reageerde furieus op de Brus...         259         no
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 29091 entries, 0 to 45396
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              29091 non-null  int64
#  1   title                   29091 non-null  str
#  2   outlet                  29091 non-null  str
#  3   date                    29091 non-null  str
#  4   authors                 29091 non-null  str
#  5   body                    29091 non-null  str
#  6   word_count              29091 non-null  int64
#  7   ai_related              29091 non-null  str
#  8   matched_keywords_title  29091 non-null  str
#  9   matched_keywords_body   29091 non-null  str
#  10  matched_keywords_all    29091 non-null  str
#  11  n_hits_title_total      29091 non-null  int64
#  12  n_hits_body_total       29091 non-null  int64
#  13  company_hits            29091 non-null  str
# dtypes: int64(4), str(10)
# memory usage: 3.3 MB

# %%
df["ai_related"].value_counts()
# Out:
# ai_related
# no     15855
# yes    13236
# Name: count, dtype: int64
