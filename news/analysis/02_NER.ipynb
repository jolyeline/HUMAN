# %% [markdown]
# # NER

# %%
#Imports
import spacy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter, defaultdict
from itertools import combinations
from fuzzywuzzy import fuzz
from wordcloud import WordCloud
import networkx as nx
nlp = spacy.load("nl_core_news_lg")
# Out:
# c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#Load the dataframe
df = pd.read_csv('..//final_df//cleaned_final_df.csv') #use the .pkl file for this script!
df.head()
# Out:
#                                                title  outlet        date  \
# 0  Chatbot Emma glimlacht na een compliment Chatb...  Parool  2015-10-23
# 1  Vera en Roos hebben het druk Vera en Roos hebb...  Parool  2015-10-23
# 2  Leer van big data-incidenten Leer van big data...  Parool  2015-01-03
# 3                                    Brieven Brieven  Parool  2015-09-03
# 4  Stad van stenen en pixels Stad van stenen en p...  Parool  2015-05-19
#
#            authors                                               body  \
# 0  BART VAN ZOELEN  'Dag Denise, hoe oud ben jij?" vragen we Denis...
# 1  BART VAN ZOELEN  Klantenservice: Virtuele medewerkers kunnen st...
# 2  Unknown Authors  Keerpunt: De doorbraak van big data \nBracht 2...
# 3  Unknown Authors  Geen vrije keuze \nVrijdag had Het Parool een ...
# 4       TRACY METZ  De talkshow Stadsleven, deze maand tegelijk me...
#
#    word_count ai_related matched_keywords_title    matched_keywords_body  \
# 0         238        yes            ['chatbot']             ['chatbots']
# 1         249        yes                     []  ['chatbot', 'chatbots']
# 2         303        yes                     []    ['slimme algoritmes']
# 3         310        yes                     []            ['algoritme']
# 4         317        yes                     []            ['algoritme']
#
#       matched_keywords_all  ...  date_parsed  year topic probability  \
# 0  ['chatbot', 'chatbots']  ...   2015-10-23  2015     8    0.153558
# 1  ['chatbot', 'chatbots']  ...   2015-10-23  2015     8    0.212454
# 2    ['slimme algoritmes']  ...   2015-01-03  2015    12    0.128177
# 3            ['algoritme']  ...   2015-09-03  2015    14    0.373948
# 4            ['algoritme']  ...   2015-05-19  2015     8    1.000000
#
#   topic_norm          topic_label_nl        topic_meta_nl  \
# 0          8  facebook en algoritmen        SOCIALE MEDIA
# 1          8  facebook en algoritmen        SOCIALE MEDIA
# 2         12                 bitcoin  BEDRIJF & FINANCIËN
# 3         14               onderwijs            ONDERWIJS
# 4          8  facebook en algoritmen        SOCIALE MEDIA
#
#                topic_label           topic_meta  ai_words
# 0  facebook and algorithms         SOCIAL MEDIA        []
# 1  facebook and algorithms         SOCIAL MEDIA        []
# 2                  bitcoin  BUSINESS & FINANCE         []
# 3               eductation            EDUCATION        []
# 4  facebook and algorithms         SOCIAL MEDIA        []
#
# [5 rows x 27 columns]

# %%
# Function to retrieve entities
def extract_entities(text, nlp, similarity_threshold=90):
    doc = nlp(text)
    entities = []
    for ent in doc.ents:
        if ent.label_ in ('PERSON'):
            entity_text = ent.text

            # Check if the new entity is a near duplicate of any of the entities already in the list
            if not any(fuzz.ratio(entity_text, entity) > similarity_threshold for entity in entities):
                entities.append(entity_text)
    return entities

# %%
# Function to get top entities for each publication type
def get_top_entities_for_category(df, publication_type, nlp, top_n=100):
    texts = df[df['outlet'] == publication_type]['body']
    all_entities = []
    for text in texts:
        all_entities.extend(extract_entities(text, nlp))
    return Counter(all_entities).most_common(top_n)

# Function to build the graph
def build_extended_graph(top_entities_by_publication_type):
    G = nx.Graph()
    
    # Add edges between publication types and entities
    for ptype in top_entities_by_publication_type:
        for entity, count in top_entities_by_publication_type[ptype]:
            G.add_edge(ptype, entity, weight=count)
    
    return G

# %%
# Extract the top 100 entities for each publication type, you can change this number
unique_publication_types = df['outlet'].unique()
top_entities_by_publication_type = {
    ptype: get_top_entities_for_category(df, ptype, nlp, top_n=100) 
    for ptype in unique_publication_types
}

# Build and save the graph
G = build_extended_graph(top_entities_by_publication_type)
nx.write_gexf(G, "shared_and_unique_entities.gexf")

# %%
def get_top_entities(df, nlp, text_col='body', top_n=20):
    """
    Iterate through df[text_col], extract entities, and return the top_n most common.
    """
    counter = Counter()
    # dropna() avoids errors if some bodies are missing
    for doc in df[text_col].dropna():
        ents = extract_entities(doc, nlp)
        counter.update(ents)
    return counter.most_common(top_n)

# %%
# Example usage:
top_20 = get_top_entities(df, nlp)
print(top_20)
# Out:
# [('May', 731), ('Amazon', 697), ('Trump', 684), ('Donald Trump', 647), ('Mark Zuckerberg', 429), ('Elon', 296), ('Sam Altman', 233), ('Tesla', 215), ('God', 159), ('Elon Musk', 155), ('Altman', 146), ('Mark Rutte', 139), ('Siri', 138), ('Huawei', 138), ('Joe', 132), ('Rutte', 129), ('Albert Heijn', 112), ('Bard', 103), ('Alexa', 103), ('Geert Wilders', 101)]

# %%
def plot_bar_chart(entities, title):
    """
    entities: list of (label, count)
    title:   string for the plot title
    """
    labels, values = zip(*entities) if entities else ([], [])
    plt.figure(figsize=(10, 5))
    plt.bar(labels, values, color='skyblue')
    plt.title(title)
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

def plot_word_cloud(entities, title):
    """
    entities: list of (label, count)
    title:    string for the plot title
    """
    freqs = {label: count for label, count in entities}
    wordcloud = WordCloud(
        width=800, height=400, background_color='white'
    ).generate_from_frequencies(freqs)
    
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title)
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
# --- Example usage with your get_top_entities() ---
#stop_20 = get_top_entities(df, nlp, text_col='body', top_n=20)

#Plot both views in one go:
plot_bar_chart(top_20, 'Top 20 Entities in Your Corpus')
plot_word_cloud(top_20, 'Word Cloud of Top 20 Entities')

# %%
top_20
# Out:
# [('May', 731),
#  ('Amazon', 697),
#  ('Trump', 684),
#  ('Donald Trump', 647),
#  ('Mark Zuckerberg', 429),
#  ('Elon', 296),
#  ('Sam Altman', 233),
#  ('Tesla', 215),
#  ('God', 159),
#  ('Elon Musk', 155),
#  ('Altman', 146),
#  ('Mark Rutte', 139),
#  ('Siri', 138),
#  ('Huawei', 138),
#  ('Joe', 132),
#  ('Rutte', 129),
#  ('Albert Heijn', 112),
#  ('Bard', 103),
#  ('Alexa', 103),
#  ('Geert Wilders', 101)]

# %%
# --- 1) Remove items that are clearly not people ---
non_persons = {'August', 'God', 'Al', 'Oranje', 'Trouw', 'May', 'Amazon', 'Huawei', 'Tesla', 'Albert Heijn'}

filtered = [(name, count) for name, count in top_20 if name not in non_persons]

# --- 2) Define merge mapping for duplicates / variants ---
merge_map = {
    'Rutte': 'Mark Rutte',
    'Mark Rutte': 'Mark Rutte',
    'Wilders': 'Geert Wilders',
    'Geert Wilders': 'Geert Wilders',
    'Trump': 'Donald Trump',
    'Donald Trump': 'Donald Trump',
    'Merkel': 'Angela Merkel',
    'Angela Merkel': 'Angela Merkel',
    'Van der Burg': 'Eric van der Burg',
    'Eric van der Burg': 'Eric van der Burg',
    'Altman': 'Sam Altman',
    'Sam Altman': 'Sam Altman',
    'Elon': 'Elon Musk', 
    
    # Others can stay as is
}

# --- 3) Merge counts based on canonical name ---
merged = defaultdict(int)
for name, count in filtered:
    canonical = merge_map.get(name, name)
    merged[canonical] += count

# --- 4) Sort by frequency descending ---
cleaned_top = sorted(merged.items(), key=lambda x: x[1], reverse=True)

# --- 5) Print result ---
for name, count in cleaned_top:
    print(f"{name}: {count}")
# Out:
# Donald Trump: 1331
# Elon Musk: 451
# Mark Zuckerberg: 429
# Sam Altman: 379
# Mark Rutte: 268
# Siri: 138
# Joe: 132
# Bard: 103
# Alexa: 103
# Geert Wilders: 101

# %%
# --- Example usage with your get_top_entities() ---
#stop_20 = get_top_entities(df, nlp, text_col='body', top_n=20)

#Plot both views in one go:
plot_bar_chart(cleaned_top, 'Most Frequently Mentioned Persons (Top 10)')
plot_word_cloud(cleaned_top, 'Word Cloud of 10 Most Frequently Mentioned Persons')

# %%
df
# Out:
#                                                    title  outlet        date  \
# 0      Chatbot Emma glimlacht na een compliment Chatb...  Parool  2015-10-23
# 1      Vera en Roos hebben het druk Vera en Roos hebb...  Parool  2015-10-23
# 2      Leer van big data-incidenten Leer van big data...  Parool  2015-01-03
# 3                                        Brieven Brieven  Parool  2015-09-03
# 4      Stad van stenen en pixels Stad van stenen en p...  Parool  2015-05-19
# ...                                                  ...     ...         ...
# 13204  De nieuwe versie van ChatGPT blundert als vano...      VK  2025-08-12
# 13205  Een superbrein dat de mens voorbijstreeft? Een...      VK  2025-06-07
# 13206  Grote AI-denker bleef gefascineerd door de men...      VK  2025-08-22
# 13207  De 'nerdy' miljardair achter DeepSeek De 'nerd...      VK  2025-01-29
# 13208    AI zoals wij die willen AI zoals wij die willen      VK  2025-08-30
#
#                 authors                                               body  \
# 0       BART VAN ZOELEN  'Dag Denise, hoe oud ben jij?" vragen we Denis...
# 1       BART VAN ZOELEN  Klantenservice: Virtuele medewerkers kunnen st...
# 2       Unknown Authors  Keerpunt: De doorbraak van big data \nBracht 2...
# 3       Unknown Authors  Geen vrije keuze \nVrijdag had Het Parool een ...
# 4            TRACY METZ  De talkshow Stadsleven, deze maand tegelijk me...
# ...                 ...                                                ...
# 13204  LAURENS VERHAGEN  1.\nOpenAI maakt de hype niet waar\nToen OpenA...
# 13205  LAURENS VERHAGEN  Technologie 'Denkende' en 'begrijpende' AI\n'C...
# 13206  LAURENS VERHAGEN  Margaret Boden (1936-2025)\nIs het geheel nieu...
# 13207      FRANK RENSEN  Liang Wenfeng\nUit het niets verscheen de AI-a...
# 13208  LAURENS VERHAGEN  Kunstmatige intelligentie Specialist pleit voo...
#
#        word_count ai_related matched_keywords_title  \
# 0             238        yes            ['chatbot']
# 1             249        yes                     []
# 2             303        yes                     []
# 3             310        yes                     []
# 4             317        yes                     []
# ...           ...        ...                    ...
# 13204         207        yes            ['chatgpt']
# 13205         297        yes                     []
# 13206         255        yes                 ['ai']
# 13207         278        yes                     []
# 13208         234        yes                 ['ai']
#
#                                    matched_keywords_body  \
# 0                                           ['chatbots']
# 1                                ['chatbot', 'chatbots']
# 2                                  ['slimme algoritmes']
# 3                                          ['algoritme']
# 4                                          ['algoritme']
# ...                                                  ...
# 13204  ['ai', 'chatgpt', 'generatieve ai', 'gpt', 'op...
# 13205  ['ai', 'anthropic', 'chatgpt', 'deepmind', 'll...
# 13206     ['ai', 'chatgpt', 'kunstmatige intelligentie']
# 13207             ['ai', 'chatbot', 'chatgpt', 'openai']
# 13208      ['ai', 'kunstmatige intelligentie', 'openai']
#
#                                     matched_keywords_all  ...  date_parsed  \
# 0                                ['chatbot', 'chatbots']  ...   2015-10-23
# 1                                ['chatbot', 'chatbots']  ...   2015-10-23
# 2                                  ['slimme algoritmes']  ...   2015-01-03
# 3                                          ['algoritme']  ...   2015-09-03
# 4                                          ['algoritme']  ...   2015-05-19
# ...                                                  ...  ...          ...
# 13204  ['ai', 'chatgpt', 'generatieve ai', 'gpt', 'op...  ...   2025-08-12
# 13205  ['ai', 'anthropic', 'chatgpt', 'deepmind', 'll...  ...   2025-06-07
# 13206     ['ai', 'chatgpt', 'kunstmatige intelligentie']  ...   2025-08-22
# 13207             ['ai', 'chatbot', 'chatgpt', 'openai']  ...   2025-01-29
# 13208      ['ai', 'kunstmatige intelligentie', 'openai']  ...   2025-08-30
#
#        year topic probability topic_norm             topic_label_nl  \
# 0      2015     8    0.153558          8     facebook en algoritmen
# 1      2015     8    0.212454          8     facebook en algoritmen
# 2      2015    12    0.128177         12                    bitcoin
# 3      2015    14    0.373948         14                  onderwijs
# 4      2015     8    1.000000          8     facebook en algoritmen
# ...     ...   ...         ...        ...                        ...
# 13204  2025    19    0.055403         19                AI-modellen
# 13205  2025    16    0.037080         16  chatbots en desinformatie
# 13206  2025    15    0.008852         15          AI en tech trends
# 13207  2025     1    0.033187          1              chipindustrie
# 13208  2025    31    0.110399         31           tech en overheid
#
#                            topic_meta_nl                  topic_label  \
# 0                          SOCIALE MEDIA      facebook and algorithms
# 1                          SOCIALE MEDIA      facebook and algorithms
# 2                    BEDRIJF & FINANCIËN                      bitcoin
# 3                              ONDERWIJS                   eductation
# 4                          SOCIALE MEDIA      facebook and algorithms
# ...                                  ...                          ...
# 13204             TECH & AI ONTWIKKELING                    AI models
# 13205               AI RISICO'S & ETHIEK  chatbots and desinformation
# 13206             TECH & AI ONTWIKKELING           AI and tech trends
# 13207  AI INFRASTRUCTUUR & CHIPINDUSTRIE                chip industry
# 13208                   POLITIEK & RECHT          tech and government
#
#                               topic_meta  ai_words
# 0                           SOCIAL MEDIA        []
# 1                           SOCIAL MEDIA        []
# 2                    BUSINESS & FINANCE         []
# 3                              EDUCATION        []
# 4                           SOCIAL MEDIA        []
# ...                                  ...       ...
# 13204              TECH & AI DEVELOPMENT        []
# 13205                  AI RISKS & ETHICS        []
# 13206              TECH & AI DEVELOPMENT        []
# 13207  AI INFRASTRUCTURE & CHIP INDUSTRY        []
# 13208                    POLITICS & LAW         []
#
# [13209 rows x 27 columns]

# %%
# 2) Define a helper that returns the 3 lists for one text
def get_entities_by_type(text, nlp):
    doc = nlp(text or "")
    persons   = list({ent.text for ent in doc.ents if ent.label_ == 'PERSON'})
    orgs      = list({ent.text for ent in doc.ents if ent.label_ == 'ORG'})
    countries = list({ent.text for ent in doc.ents if ent.label_ == 'GPE'})
    return persons, orgs, countries

# 3) Apply it to every row and expand into 3 new columns
df[['persons', 'orgs', 'countries']] = (
    df['body']
      .fillna("")  # avoid passing NaN into the nlp pipeline
      .map(lambda txt: get_entities_by_type(txt, nlp)) 
      .apply(pd.Series)  # turns each (persons, orgs, countries) tuple into 3 columns
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 13
#       9 # 3) Apply it to every row and expand into 3 new columns
#      10 df[['persons', 'orgs', 'countries']] = (
#      11     df['body']
#      12       .fillna("")  # avoid passing NaN into the nlp pipeline
# ---> 13       .map(lambda txt: get_entities_by_type(txt, nlp))
#      14       .apply(pd.Series)  # turns each (persons, orgs, countries) tuple into 3 columns
#      15 )
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\pandas\core\series.py:4675, in Series.map(self, func, na_action, engine, **kwargs)
#    4673 if callable(func):
#    4674     func = functools.partial(func, **kwargs)
# -> 4675 new_values = self._map_values(func, na_action=na_action)
#    4676 return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4677     self, method="map"
#    4678 )
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\pandas\core\base.py:1020, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1017 arr = self._values
#    1019 if isinstance(arr, ExtensionArray):
# -> 1020     return arr.map(mapper, na_action=na_action)
#    1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\pandas\core\arrays\base.py:2744, in ExtensionArray.map(self, mapper, na_action)
#    2724 def map(self, mapper, na_action: Literal["ignore"] | None = None):
#    2725     """
#    2726     Map values using an input mapping or function.
#    2727
#    (...)   2742         a MultiIndex will be returned.
#    2743     """
# -> 2744     return map_array(self, mapper, na_action=na_action)
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\pandas\core\algorithms.py:1710, in map_array(arr, mapper, na_action)
#    1708 values = arr.astype(object, copy=False)
#    1709 if na_action is None:
# -> 1710     return lib.map_infer(values, mapper)
#    1711 else:
#    1712     return lib.map_infer_mask(values, mapper, mask=isna(values).view(np.uint8))
#
# File pandas/_libs/lib.pyx:3071, in pandas._libs.lib.map_infer()
# -> 3071 'Could not get source, probably due dynamically evaluated source code.'
#
# Cell In[23], line 13, in <lambda>(txt)
# ---> 13       .map(lambda txt: get_entities_by_type(txt, nlp))
#
# Cell In[23], line 3, in get_entities_by_type(text, nlp)
#       2 def get_entities_by_type(text, nlp):
# ----> 3     doc = nlp(text or "")
#       4     persons   = list({ent.text for ent in doc.ents if ent.label_ == 'PERSON'})
#       5     orgs      = list({ent.text for ent in doc.ents if ent.label_ == 'ORG'})
#       6     countries = list({ent.text for ent in doc.ents if ent.label_ == 'GPE'})
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\spacy\language.py:1053, in Language.__call__(self, text, disable, component_cfg)
#    1051     error_handler = proc.get_error_handler()
#    1052 try:
# -> 1053     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1054 except KeyError as e:
#    1055     # This typically happens if a component is not initialized
#    1056     raise ValueError(Errors.E109.format(name=name)) from e
#
# File spacy/pipeline/trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
# ---> 52 'Could not get source, probably due dynamically evaluated source code.'
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\spacy\pipeline\edit_tree_lemmatizer.py:133, in EditTreeLemmatizer.predict(self, docs)
#     131     assert len(guesses) == n_docs
#     132     return guesses
# --> 133 scores = self.model.predict(docs)
#     134 assert len(scores) == n_docs
#     135 guesses = scores2guesses(docs, scores)
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\thinc\model.py:334, in Model.predict(self, X)
#     330 def predict(self, X: InT) -> OutT:
#     331     """Call the model's `forward` function with `is_train=False`, and return
#     332     only the output, instead of the `(output, callback)` tuple.
#     333     """
# --> 334     return self._func(self, X, is_train=False)[0]
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\thinc\layers\with_array.py:42, in forward(model, Xseq, is_train)
#      40     return model.layers[0](Xseq, is_train)
#      41 else:
# ---> 42     return cast(Tuple[SeqT, Callable], _list_forward(model, Xseq, is_train))
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\thinc\layers\with_array.py:77, in _list_forward(model, Xs, is_train)
#      75 lengths = NUMPY_OPS.asarray1i([len(seq) for seq in Xs])
#      76 Xf = layer.ops.flatten(Xs, pad=pad)
# ---> 77 Yf, get_dXf = layer(Xf, is_train)
#      79 def backprop(dYs: ListXd) -> ListXd:
#      80     dYf = layer.ops.flatten(dYs, pad=pad)
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\thinc\layers\softmax.py:71, in forward(model, X, is_train)
#      69 W = cast(Floats2d, model.get_param("W"))
#      70 b = cast(Floats1d, model.get_param("b"))
# ---> 71 Y = model.ops.affine(X, W, b)
#      73 if normalize:
#      74     Y = model.ops.softmax(Y, temperature=temperature)
#
# File c:\Users\joly-\Github\HUMAN\.venv312\Lib\site-packages\thinc\backends\ops.py:263, in Ops.affine(self, X, W, b)
#     259 def affine(self, X: Floats2d, W: Floats2d, b: Floats1d) -> Floats2d:
#     260     """Apply a weights layer and a bias to some inputs, i.e.
#     261     Y = X @ W.T + b
#     262     """
# --> 263     Y = self.gemm(X, W, trans2=True)
#     264     Y += b
#     265     return Y
#
# KeyboardInterrupt:

# %%
df.head()
# Out:
#                                                title  outlet        date  \
# 0  Chatbot Emma glimlacht na een compliment Chatb...  Parool  2015-10-23
# 1  Vera en Roos hebben het druk Vera en Roos hebb...  Parool  2015-10-23
# 2  Leer van big data-incidenten Leer van big data...  Parool  2015-01-03
# 3                                    Brieven Brieven  Parool  2015-09-03
# 4  Stad van stenen en pixels Stad van stenen en p...  Parool  2015-05-19
#
#            authors                                               body  \
# 0  BART VAN ZOELEN  'Dag Denise, hoe oud ben jij?" vragen we Denis...
# 1  BART VAN ZOELEN  Klantenservice: Virtuele medewerkers kunnen st...
# 2  Unknown Authors  Keerpunt: De doorbraak van big data \nBracht 2...
# 3  Unknown Authors  Geen vrije keuze \nVrijdag had Het Parool een ...
# 4       TRACY METZ  De talkshow Stadsleven, deze maand tegelijk me...
#
#    word_count ai_related matched_keywords_title    matched_keywords_body  \
# 0         238        yes            ['chatbot']             ['chatbots']
# 1         249        yes                     []  ['chatbot', 'chatbots']
# 2         303        yes                     []    ['slimme algoritmes']
# 3         310        yes                     []            ['algoritme']
# 4         317        yes                     []            ['algoritme']
#
#       matched_keywords_all  ...  probability  topic_norm  \
# 0  ['chatbot', 'chatbots']  ...     0.153558           8
# 1  ['chatbot', 'chatbots']  ...     0.212454           8
# 2    ['slimme algoritmes']  ...     0.128177          12
# 3            ['algoritme']  ...     0.373948          14
# 4            ['algoritme']  ...     1.000000           8
#
#            topic_label_nl        topic_meta_nl              topic_label  \
# 0  facebook en algoritmen        SOCIALE MEDIA  facebook and algorithms
# 1  facebook en algoritmen        SOCIALE MEDIA  facebook and algorithms
# 2                 bitcoin  BEDRIJF & FINANCIËN                  bitcoin
# 3               onderwijs            ONDERWIJS               eductation
# 4  facebook en algoritmen        SOCIALE MEDIA  facebook and algorithms
#
#             topic_meta ai_words  \
# 0         SOCIAL MEDIA       []
# 1         SOCIAL MEDIA       []
# 2  BUSINESS & FINANCE        []
# 3            EDUCATION       []
# 4         SOCIAL MEDIA       []
#
#                                              persons  \
# 0  [Fleur, Emma, Dokman, Denise van de Nederlands...
# 1  [Vera, Francis, Dokman, Roos, Maud, Dirk Jan D...
# 2                                      [Zwarte Piet]
# 3                                 [Simone Kukenheim]
# 4                                        [Ger Baron]
#
#                                                 orgs  \
# 0  [Robeco, NLE, Wie Yamuda, Ohra, VGZ, Coolblue,...
# 1  [Robeco, KPN, Bol.com, Ohra, Nederlandse Energ...
# 2                         [Financieele Dagblad, ING]
# 3                                                 []
# 4                                                 []
#
#                             countries
# 0                                  []
# 1                  [Yamuda, Randstad]
# 2                                  []
# 3  [Amsterdam, Kukenheim, schoolkeus]
# 4                         [Amsterdam]
#
# [5 rows x 30 columns]

# %%
df.to_csv('df_with_NER.csv')
